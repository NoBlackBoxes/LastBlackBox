# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
# img = cv2.imread("pictures/captured_frame.png")
img = cv2.imread("../pictures/sample.jpg")

rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(rgb)
plt.title("Input image")
plt.axis("off")
plt.show()

# %%
model = YOLO("yolov8n.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 76.1MB/s 0.1s

# %%
results = model(img)
# Out:
# 0: 640x640 1 person, 1 sports ball, 2 tennis rackets, 95.6ms
# Speed: 15.8ms preprocess, 95.6ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 640)

# %%
annotated = results[0].plot()

annotated = cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB)

plt.imshow(annotated)
plt.title("Object detection")
plt.axis("off")
plt.show()

# %%
for box in results[0].boxes:
    
    cls_id = int(box.cls[0])
    conf = float(box.conf[0])
    
    print(model.names[cls_id], round(conf, 2))
# Out:
# person 0.88
# sports ball 0.83
# tennis racket 0.54
# tennis racket 0.26
